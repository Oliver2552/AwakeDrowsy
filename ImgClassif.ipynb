# %% [markdown]
# # **`Using Classification to Classify Awake/Drowsy`**

# %%
import os
import torch
import random
import numpy as np
import warnings
import cv2
import PIL.Image
import matplotlib.pyplot as plt
from insightface.app import FaceAnalysis
from torch import nn, optim
from torch.utils.data import DataLoader
from torchsummary import summary
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchvision import datasets, transforms, models
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ### Using `InsightFace` to crop images (that were gathered in awake_drowsy.ipynb as well as google images of faces) and will use those for EDA and modelling.
#
# ### Before that we'll feed live camera feed into IsightFace to demonstrate how its working.

# %% [markdown]
# ### **`Live Camera Feed into InsightFace`**

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
app = FaceAnalysis(name='buffalo_l')
app.prepare(ctx_id=0, det_size=(160, 160))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:69: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (160, 160)

# %%
capture = cv2.VideoCapture(0)

# %%
while True:
    ret, frame = capture.read()

    faces = app.get(frame)

    for face in faces:
        bbox = face.bbox.astype(int)
        cv2.rectangle(frame, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)

    image_crop = frame[bbox[1]:bbox[3], bbox[0]:bbox[2], :]

    cv2.imshow('InsighFace Detecting Live Feed', image_crop)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### **`Accessing Images and Cropping`**

# %%
data = '/Users/oscaramirmansour/AwakeDrowsy/data/Images'

output_folder = '/Users/oscaramirmansour/AwakeDrowsyObjDetec/data/Images_cropped'

# %% [markdown]
# All images in folder

# %%
images = [os.path.join(data, filename) for filename in os.listdir(data) if filename.endswith('.jpg')]

images
# Out:
# ['/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.4cea0ede-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ba625a34-8ed0-11ee-bc9a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.75496d6c-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.e95c0552-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6defa68a-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.d2aac3e8-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.359c4e72-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.cb4770ce-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.d16f16c8-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.953787e4-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.f72a8be2-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a348270a-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ad1c9e28-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8457-1.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.9f96b572-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a8370010-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7de6fffe-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.haircuts-for-round-face-2000-dbc9189937e84a028d3ca7be79f072a5.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.e46d52c6-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.20a91d10-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.996d0016-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b3e689ba-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1bbb2230-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.39e69050-8ed0-11ee-bde8-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.f5e3a9e4-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.95bb09b8-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.5c70418a-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.5de00c80-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.istockphoto-621981240-612x612.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.00bec18a-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8e5b5678-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.0bca2d80-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.shutterstock_575234722-1100x490.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.96f5f43c-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.Angelina-Jolie-100x130cm-2013.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.da9160b2-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.13223f6e-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.vf823-pfiffer.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.081a868a-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ecabfc70-8ed0-11ee-bc9a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.4a733090-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.30b1bc12-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c2ad6176-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a8e6bae4-8ecf-11ee-bde8-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.26cbb2d4-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.adc4a45e-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.cdbe11dc-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1f6e12c0-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.e5a82490-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f81a2164-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.509721b6-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.7dd87506e4b1a7bc343f91c0c97f5436.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b036bf92-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f95a3762-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.38109f46-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.attachment-Drowsy-Driver.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7cae17ce-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.e3321928-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ee450ea6-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.what-time-is-it-royalty-free-image-1616546095.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.69124688-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.depositphotos_190376900-stock-photo-overworked-young-woman-sitting-workplace.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.d65c8d96-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.depositphotos_603995032-stock-photo-man-napping-his-car.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.75535c3e-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.35443855-tired-sleepy-young-man-yawning.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.woman-is-sleeping-sofa-feeling-relax-tired-day_39688-3699.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f468defc-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.aa0f4936-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.photo-1542489136-d03f82c9c91e.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.9a1ffd68-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.06ddc6c4-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8aadf332-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.aaa97224-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.81948ba8-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.Heldiney-homepage.2e16d0ba.fill-768x500.jpegquality-40.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.cc82d64a-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.259000be-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.4e24ce88-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.4bae1ad8-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6a426be4-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b170a4ea-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c8d11160-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.tired-woman-syndrome-tired-woman-sydnrome.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.drowsy-driving-girl-12.6.17.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.portrait-tired-drowsy.worker-sleeping-car-260nw-472368733.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.ca0c292a-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c175d464-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.istockphoto-1410538853-170667a.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.9c900caa-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.aa2bd362-8ecf-11ee-bde8-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.6217d5bc775582e77cc92b90_man-sleeping-on-laptop-n.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.sleepy-fatigued-asian-woman-falls-600nw-2317751267.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.discipline-employees-tired-work.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.90cf33a2-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.befe93e2-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.gettyimages-629866358-612x612.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6555c748-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f45wsgdf4drowsy-1.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.5f268448-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.618abc9cdfbae01bc36d2ce5_hero_advanced_drowsiness.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.r3w45tegfe2014-07-24-ino.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.920aecf2-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.9b57260c-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.4935d624-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.Donald-Kaufman-Glenwood-Attorney-drowsy-Driver.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.d3e5292e-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.bc896100-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.be-well-fight-off-fatigue.jpg.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7060c7aa-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3cf93388-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.2bbeae68-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.de443798-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.e0bc38b8-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a9717f5a-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1a7ea220-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.here-is-why-you-cannot-sleep-right-now-gq-may-2020.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b5b6be59598fd143a0d71eb61c.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.f9a0e9d4-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.bbb71cc6-8ed0-11ee-bc9a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3a84405c-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.231b0644-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.21.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a5bf4da6-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c573e9df37d0c494c66abc571d35f27c.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.145c744e-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c3e64378-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c5221668-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ea938d28-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.30b33fe569c104910f9984eca6881393.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.few3r4rf4wseimages.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.0a908446-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.01fa1cfc-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.2807622e-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6b84e06a-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.e6e4523e-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.celebrities-mixed-faces-morphy-me-5eb3bc2bb28b7-png__700.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.fa944ba4-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.16ce6e44-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7f217bd8-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.4c7bf673589d39e048629446763e2cfb.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.dbc8380c-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.ab534cac-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.DL_u509337_017.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.294b88cc-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.0d0659ee-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.8408cd8e-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.0e3dc554-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.41de0432-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.a79acf54-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f5a35f04-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ff850d10-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.front-portrait-woman-beauty-face-260nw-497756323.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.a1736ee2-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.345f7868-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.drowsy-driving-accidents.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f0bf3472-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.dd04627c-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7cad249c-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.d03389ec-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.9be3cd52-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b51e284c-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.09554166-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.394c648a-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.85449e00-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6b7d7d50-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1000_F_235302510_HEaMQ8T0aUEQJ84o8nNuQjYrN1PrGClN.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f3309390-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.quotes-from-my-id-is-gangnam-beauty-kdrama.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.Erez-Freud-792x1024.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.819663cc-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1000_F_613053602_fM5HbiB7fWxCZLlkHHsKFhVrFemruMop.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.istockphoto-1352871318-612x612.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6f26a12a-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a4842222-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.ac8b6cbc-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.9dca06e8-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.photo-1680506727554-3ba2d9f99129.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.bb45d152-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.fd0a0f40-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.458ac250-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.f8652c24-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6560a43a-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7b7331ac-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.85449ed0-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.53115435-front-view-of-a-tired-man-sleeping-on-a-couch-at-home.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.fbcf0748-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.8f189ca4-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.d5233420-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake._129423268_danhill.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.be3450a4-8ed0-11ee-bc9a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.DrAxeAlwaysTired_FB.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.2cfb89a4-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.03352cce-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.bf6fd9ca-8ed0-11ee-bc9a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a20ba97a-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.9f02b456-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.31ecbfdc-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3f6b0f6a-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c7993a84-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.a52825f0-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8-What-is-Sleep-Debt-and-What-Role-Does-it-Play-in-Drowsy-Driving.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.05a4a2be-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.790824c5afa57f53128e38a394a63216.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.png-clipart-woman-with-black-hair-taking-selfie-face-brown-hair-front-people-faces.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.51d2d368-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.2e359594-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.a2ace842-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.0f7b5abc-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6907c3be-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.2a84629a-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.dd7c476e32078b6dd8f3ad20c505cd7d.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a0d113ec-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.fadb7d1e-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.54449096-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.ffc3c4da-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.cef9778a-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ef815b62-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.istockphoto-519543349-612x612.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.9e590b06-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.fe854364-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.aefce804-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.24583108-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.ruba-ghazal-course-20230521.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.fc132d08-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6f321e8a-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.fe487068-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.40a459cc-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.Drowsy-Driver-Accident-Lawyer.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.bdc29b18-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.76843cde-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8f9479a2-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f1f6c602-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6dfb6332-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.df801686-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.9480bea8-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ebcde724-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.Brad-Pitt_1-2000-e8a294b80b034e659785ad813d3f02f2.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3b2041c8-8ed0-11ee-bde8-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.ed091ac8-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.9345d500-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.tired-biz-man1.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1e329e26-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b8cf45f2-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.9d1ead9a-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6cbd3ef0-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.closeup-mature-man-sleeping-while-260nw-1174636609.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.sleepy-asian-girl-freelancer-student-260nw-2141298833.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b2aa8204-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.10b26fa6-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.iStock-1337844041.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.8a2bd724-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8976b620-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.DrAxeAlwaysTired_Thumbnail.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c65ddb34-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.9aa83310-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7de88da4-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7a397648-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.GettyImages-482460696.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8be859c2-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.ylannoel-cd132533560b44978aee0dd556c9e7a2.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.11e97590-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1000_F_274517203_akHwfZSNyHJRD5rKfWScy8JJPFempnwF.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.4f5fdae0-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.a8d5a718-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b7938fae-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7b720820-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.046c8db2-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3323f4ba-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.e8206aca-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.431760fa-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.64211226-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.8dddb964-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.46c2296a-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.8b68a4be-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.98349d1c-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.Byrdie-Boy-How-to-Determine-Your-Face-ShapeV2-8bb786c1c17a420288dad1cde497cf30.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6a4a7ec6-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.c039134a-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.e1f73a16-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3e33f332-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3544324drowsydriving.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.morphy-me-celebrity-face-mashups-15.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.f34a7988-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.a6623dfc-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.2f6d710c-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.abe30844-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.Asleep-in-Car-WL.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1943041e-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6cb45220-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.common-sense1.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.1_twWCE0zWUKV4v9Jnywic1A.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.706922b2-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1595f7a4-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.df4vrgfdv3_0848201.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.f4a2397e-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.istockphoto-504241925-612x612.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.8ca332e0-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.47fb921c-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.530ccf90-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.istockphoto-1352871318-170667a.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.360_F_293561227_EoFY2CFfqi1XVPnH9yChoU2mzx6YDB6I.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1cf67226-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.a3ec7a24-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.36d54b2c-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7f247638-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.fd4ccc10-8d56-11ee-b10a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.epositphotos_431037154-stock-photo-a-portrait-of-a-tired.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3bbd643a-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.Tired_business_woman.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.60728644-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.21e38166-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.b658bd62-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.445011a6-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.a0398ce6-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.c0aa0a72-8ed0-11ee-bc9a-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.ba0a77ca-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.sd345egistockphoto-1311193318-640x640.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.dan-jpsp2-3-_custom-98d6a8ae1900e40a374e983be220f91b7ead7c13-s1100-c50.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.1808e230-8d6d-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.8d204642-8a54-11ee-b275-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.6691aee2-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.hong-kong-2543130_960_720.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.quiz-stock-1.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.f6e0663c-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.7a370988-8d6c-11ee-9868-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.3637ab60-8ed0-11ee-bde8-784f434cfd22.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.Screenshot 2023-11-30 at 21.00.02.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/awake.g43443efsdgdsfirl.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.female-laptop-tired-nap-napping-1296x728-header.jpg',
#  '/Users/oscaramirmansour/AwakeDrowsy/data/Images/drowsy.a6fb2e60-8a54-11ee-b275-784f434cfd22.jpg']

# %% [markdown]
# Dividing above images into `awake` vs. `drowsy`

# %%
awake_imgs = [img_path for img_path in images if os.path.basename(img_path).startswith('awake')]

drowsy_imgs = [img_path for img_path in images if os.path.basename(img_path).startswith('drowsy')]

print(f'Number of awake images: {len(awake_imgs)}')

print(f'Number of drowsy images: {len(drowsy_imgs)}')

# %% [markdown]
# Feeding images through InsightFace and outputing to output folder 'Images_cropped'

# %%
for img_path in awake_imgs + drowsy_imgs:
    print(f'Image: {img_path}')
    
    try:
        img = cv2.imread(img_path)
        output_path = os.path.join(output_folder, os.path.basename(img_path))
        
        faces = app.get(img)

        if len(faces) > 0:
            bbox = faces[0]['bbox']
            # was getting error: `TypeError: slice indices must be integers or None or have an __index__ method`
            # so going to convert bounding box coordinates to int
            bbox = [int(coord) for coord in bbox]
            img_face = img[bbox[1]:bbox[3], bbox[0]:bbox[2], :]

            # saving cropped images to output folder: 'Images_cropped'
            output_path = os.path.join(output_folder, os.path.basename(img_path))
            cv2.imwrite(output_path, img_face)
        else:  
            print(f'No face detected in {img_path}')
    except:
        pass

# %% [markdown]
# Because we're training a classification model, we manually split the data into training, validation and test folders (which are found in the 'images_cropped' folder)

# %% [markdown]
# ### **`Exploratory Data Analysis`**

# %% [markdown]
# ### Image Paths
#
# we can perform some EDA on the training data

# %%
train_data = '/Users/oscaramirmansour/AwakeDrowsy/data/Images_cropped/train'

test_data = '/Users/oscaramirmansour/AwakeDrowsy/data/Images_cropped/test'

valid_data = '/Users/oscaramirmansour/AwakeDrowsy/data/Images_cropped/validation'

# %% [markdown]
# ### Sample Images
#
# Let's have a look at the a random sample of the types of images we're working with

# %%
class_folders = [folder for folder in os.listdir(train_data) if os.path.isdir(os.path.join(train_data, folder))]

class_folders
# Out:
# ['drowsy', 'awake']

# %%
# Display sample images
fig, axes = plt.subplots(nrows=len(class_folders), ncols=3, figsize=(10, 5 * len(class_folders)))

for i, class_folder in enumerate(class_folders):
    class_path = os.path.join(train_data, class_folder)
    image_files = [file for file in os.listdir(class_path) if file.endswith('.jpg')]
    sample_images = random.sample(image_files, 3)

    for j, image_file in enumerate(sample_images):
        image_path = os.path.join(class_path, image_file)
        img = Image.open(image_path)
        axes[i, j].imshow(img)
        axes[i, j].set_title(f'{class_folder} - {image_file}')
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Class Distribution
#
# Despite having made my own dataset and am aware of the class distributions, lets have a look at it nonetheless.
#
# We can see that they are almost identical - there are a tiny bit more awake images but i dont think there will be an issue of uneven classes.

# %%
class_counts = {class_folder: len(os.listdir(os.path.join(train_data, class_folder))) for class_folder in class_folders}

plt.bar(class_counts.keys(), class_counts.values())
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Class Distribution')
plt.show()

# %% [markdown]
# ### Let's have a look at the image size
#
# Ideally we'd want uniform image sizes which will help with computational and memory efficiency. Having size consitent images also makes augmentation processes easier to perform.
#
# We're only working with ~140 images in each class so not too worried about computational efficiency at this level however, at much greater number of images, this is an important factor to consider.

# %%
image_sizes = []

for class_folder in class_folders:
    class_path = os.path.join(train_data, class_folder)
    for image_file in os.listdir(class_path):
        if image_file.endswith('.jpg'):
            image_path = os.path.join(class_path, image_file)
            img = Image.open(image_path)
            image_sizes.append(img.size)

# Histogram of image sizes
sizes_x, sizes_y = zip(*image_sizes)
plt.hist(sizes_x, bins=30, alpha=0.5, label='Width')
plt.hist(sizes_y, bins=30, alpha=0.5, label='Height')
plt.xlabel('Size')
plt.ylabel('Frequency')
plt.legend()
plt.title('Distribution of Image Sizes')
plt.show()

# %% [markdown]
# The difference in image sizes may be a problem so we'll need to ensure they'll all the same size.

# %% [markdown]
# ### Examining Color Channels
#
# Here we're trying to make sure that all our images are in RGB format so as to maintain consistency and thus maximise computational and memory efficiency.

# %%
color_channels = []

for class_folder in class_folders:
    class_path = os.path.join(train_data, class_folder)
    for image_file in os.listdir(class_path):
        if image_file.endswith('.jpg'):
            image_path = os.path.join(class_path, image_file)
            img = Image.open(image_path)
            num_channels = img.getbands()
            color_channels.append(len(num_channels))

# histogram of color channels
plt.hist(color_channels, bins=3, alpha=0.5)
plt.xlabel('Num of Color Channels')
plt.ylabel('Freq')
plt.title('Dist of Color Channels')
plt.show()

# %% [markdown]
# # **`Classification Model`**

# %% [markdown]
# ### Were going to use the images that were generated in awake_drowsy.ipynb (the YOLO model) as well as google images of random faces and use `InsightFace` to crop the images. InsightFace will automatically detect bounding boxes as opposed to `LabelImg` which requires users to manually draw bounding boxes and label images.
#
# ### We'll then augment/transform images using PyTorch.

# %% [markdown]
# ### Let's do some transformations:
#
# * First we're going to convert our images to PyTorch tensors which sclae the images pixel values from its normal range of [0,255] to [0,1]. This is a standard step when preparing images for convolutional neural networks.
#
# * We're then going to normalise the tensor pixel values (subtracting mean and dividing by std dev for each color channel). This will then further scale the pixel value range from [-1, 1]. This will ulitmately help stabilize the learning during training.

# %%
mean = [0.5, 0.5, 0.5]
std = [0.5, 0.5, 0.5]

# %%
transform_pipeline_train = transforms.Compose([

    transforms.Resize((320, 320)), # want to ensure consistent image sizes
    transforms.RandomRotation(degrees=30),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.0, hue=0.0),
    transforms.RandomPerspective(distortion_scale=0.5, p=0.6),
    transforms.ToTensor(),
    #transforms.Normalize(mean=mean, std=std)

])

# %% [markdown]
# We only want to resize, convert to tensor and normalize test images - any other transformations/augmentations shouldn't be carried out as that isnt reflective of real life data.

# %%
transform_pipeline_test = transforms.Compose([

    transforms.Resize((320, 320)), # want to ensure consistent image sizes
    transforms.ToTensor(),
    #transforms.Normalize(mean=mean, std=std)

])

# %%
transform_pipeline_valid = transforms.Compose([

    transforms.Resize((320, 320)),
    transforms.ToTensor(),
    #transforms.Normalize(mean=mean, std=std)

])

# %% [markdown]
# ### Bringing in our datasets

# %%
train_dataset = datasets.ImageFolder(root=train_data, transform=transform_pipeline_train)

test_dataset = datasets.ImageFolder(root=test_data, transform=transform_pipeline_test)

valid_dataset = datasets.ImageFolder(root=valid_data, transform=transform_pipeline_valid)

# %% [markdown]
# ### Defining our data loaders
#
# These will handle parameters like handling the batches of data we choose to train and if we decide whether to shuffle our data or not.
#
# Here, we will shuffle and will set batch sizes to 16 given that the computer used does not have a dedicated GPU and in general isnt the greatest.

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False) 
# unlike with training data, we dont want to shuffle test data so as to not introduce any potential variability in results and also because real world data isnt shuffled and arrives in order.

valid_loader = DataLoader(valid_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# ### Model selection
#
# We're going to be using a pre-trained convolutional neural network for image handling - ResNet18

# %%
model = models.resnet18(pretrained=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# Given that we only have two classes: 'Awake' and 'Drowsy' we want to perform a binary classification and so we can modify the fully connected layers like so:

# %%
model.fc = nn.Sequential(
    # input layer with an the output size of 256 (model 3 will have 128)
    nn.Linear(model.fc.in_features, 128),
    
    # using a rectified linear activation function, which will replace all negative values with 0.
    nn.ReLU(),

    # regularization technique to prevent overfitting - here we're setting a fraction of 50% of input units to zero while training which ultimately steers the model in such a way that encourages the model to train on several pathways 
    # (Model 3 will have 0.3 droppeout instead of 0.5)
    nn.Dropout(0.3), 

    # final layer which corresponds to the output of the previous 2D output.
    nn.Linear(128, 2),

    nn.Softmax(dim=-1) # produce probabilities

)

# %% [markdown]
# ### Defining an optimizer and loss function

# %%
lr = 0.00005
lr_ratio = 0.5
patience = 2
weight_decay = 1e-4 # 1e-6 for model 3 (best model yet)

#loss_function = nn.BCELoss(weight=None, size_average=None) # Binary cross-entropy loss, which is appropriate given that we're performing binary classification.
loss_function = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# going to add a scheduler to dynamically adjust the learning rate throughout train to help convergence.
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', patience=patience, factor=lr_ratio)

# %% [markdown]
# ### Setting training duration - Epochs.
#
# In our object detection approach, our initial model (consisting of 30 images of both classes) trained for 500 epochs and post results our 'metrics/mAP-0.5' indicated that at around ~50 epochs a ~ mean average precision was achieved and so subesquent models trained over shorter periods - the next model trained for 100 epochs albeit now training on ~130 images for each class and ultimately we the final model trained on 30 epochs however with 141 images from each class.
#
# Given that this approach is image classifcation we can start with 50 epochs and evaluate.
#
# We should note that this is done locally and without a dedicated GPU so training/convergence will  inevitably take longer.

# %%
epochs = 25

# %% [markdown]
# ### Checking for CUDA for parallel computing
#
# As mentioned above, will be training on hardware thats lacks a GPU however, I do own a computer with an Nvidia RTX 3070 (8GB of VRAM) so it would be interesting to come back to this problem when I have access to it.
#
# As such, will implement a check for CUDA availability, else use CPU:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)

# %% [markdown]
# ### Training for specified epochs

# %%
# evaluating training data
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct_pred = 0
    total_samples = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)

        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, pred = torch.max(outputs.data, 1)
        total_samples += labels.size(0)
        correct_pred += np.sum((pred == labels).cpu().numpy())
    
    # evaluating validation data
    model.eval()
    running_loss_val = 0.0
    correct_pred_val = 0
    total_samples_val = 0

    with torch.no_grad():
        for inputs_val, labels_val in valid_loader:
            inputs_val, labels_val = inputs_val.to(device), labels_val.to(device)
            
            outputs_val = model(inputs_val)
            loss_val = loss_function(outputs_val, labels_val)

            running_loss_val += loss_val.item()

            _, pred_val = torch.max(outputs_val.data, 1)
            total_samples_val += labels_val.size(0)
            correct_pred_val += (pred_val == labels_val).sum().item()

    scheduler.step(running_loss_val / len(valid_loader))  # adjusting learning rate at end of every epoch

    # Retrieving and appending current learning rate to above list
    curr_lr = optimizer.param_groups[0]['lr']

    print(f'Current Epoch {epoch + 1}/{epochs} | Training Loss: {running_loss / len(train_loader)} | Training Accuracy: {correct_pred / total_samples}')
    print(f'Current Epoch: {epoch + 1}/{epochs} | Validation Loss: {running_loss_val / len(valid_loader)} | Validation Accuracy: {correct_pred_val / total_samples_val}')
    print(f'Current Learning Rate: {curr_lr}\n')
# Out:
# Current Epoch 1/25 | Training Loss: 0.6372807590585006 | Training Accuracy: 0.6996587030716723
# Current Epoch: 1/25 | Validation Loss: 0.646368682384491 | Validation Accuracy: 0.7222222222222222
# Current Learning Rate: 5e-05
#
# Current Epoch 2/25 | Training Loss: 0.4936348999801435 | Training Accuracy: 0.9078498293515358
# Current Epoch: 2/25 | Validation Loss: 0.47333552440007526 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 5e-05
#
# Current Epoch 3/25 | Training Loss: 0.40598262768042714 | Training Accuracy: 0.9488054607508533
# Current Epoch: 3/25 | Validation Loss: 0.4032081961631775 | Validation Accuracy: 0.9166666666666666
# Current Learning Rate: 5e-05
#
# Current Epoch 4/25 | Training Loss: 0.3777696584400378 | Training Accuracy: 0.962457337883959
# Current Epoch: 4/25 | Validation Loss: 0.4051162898540497 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 2.5e-05
#
# Current Epoch 5/25 | Training Loss: 0.3660804801865628 | Training Accuracy: 0.9658703071672355
# Current Epoch: 5/25 | Validation Loss: 0.397114763657252 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 2.5e-05
#
# Current Epoch 6/25 | Training Loss: 0.3754340786682932 | Training Accuracy: 0.9658703071672355
# Current Epoch: 6/25 | Validation Loss: 0.38012715180714923 | Validation Accuracy: 0.9166666666666666
# Current Learning Rate: 2.5e-05
#
# Current Epoch 7/25 | Training Loss: 0.34424804700048345 | Training Accuracy: 0.9829351535836177
# Current Epoch: 7/25 | Validation Loss: 0.40554506580034894 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 1.25e-05
#
# Current Epoch 8/25 | Training Loss: 0.34428693432556956 | Training Accuracy: 0.9863481228668942
# Current Epoch: 8/25 | Validation Loss: 0.42823557058970135 | Validation Accuracy: 0.8333333333333334
# Current Learning Rate: 1.25e-05
#
# Current Epoch 9/25 | Training Loss: 0.3428195558096233 | Training Accuracy: 0.9829351535836177
# Current Epoch: 9/25 | Validation Loss: 0.4071178138256073 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 1.25e-05
#
# Current Epoch 10/25 | Training Loss: 0.34700290309755427 | Training Accuracy: 0.9795221843003413
# Current Epoch: 10/25 | Validation Loss: 0.41559269030888873 | Validation Accuracy: 0.8333333333333334
# Current Learning Rate: 6.25e-06
#
# Current Epoch 11/25 | Training Loss: 0.34547739593606247 | Training Accuracy: 0.9761092150170648
# Current Epoch: 11/25 | Validation Loss: 0.3989490469296773 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 6.25e-06
#
# Current Epoch 12/25 | Training Loss: 0.34400115985619395 | Training Accuracy: 0.9795221843003413
# Current Epoch: 12/25 | Validation Loss: 0.3927254279454549 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 6.25e-06
#
# Current Epoch 13/25 | Training Loss: 0.3400854436974776 | Training Accuracy: 0.9829351535836177
# Current Epoch: 13/25 | Validation Loss: 0.40601317087809247 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 3.125e-06
#
# Current Epoch 14/25 | Training Loss: 0.345456273932206 | Training Accuracy: 0.9761092150170648
# Current Epoch: 14/25 | Validation Loss: 0.4095003306865692 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 3.125e-06
#
# Current Epoch 15/25 | Training Loss: 0.341945303113837 | Training Accuracy: 0.9761092150170648
# Current Epoch: 15/25 | Validation Loss: 0.41616647442181903 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 3.125e-06
#
# Current Epoch 16/25 | Training Loss: 0.337781233222861 | Training Accuracy: 0.9829351535836177
# Current Epoch: 16/25 | Validation Loss: 0.3932006557782491 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 1.5625e-06
#
# Current Epoch 17/25 | Training Loss: 0.3573049777432492 | Training Accuracy: 0.9761092150170648
# Current Epoch: 17/25 | Validation Loss: 0.38932300607363385 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 1.5625e-06
#
# Current Epoch 18/25 | Training Loss: 0.3436621474592309 | Training Accuracy: 0.9795221843003413
# Current Epoch: 18/25 | Validation Loss: 0.41504987080891925 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 1.5625e-06
#
# Current Epoch 19/25 | Training Loss: 0.34496147695340607 | Training Accuracy: 0.9795221843003413
# Current Epoch: 19/25 | Validation Loss: 0.40605111916859943 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 7.8125e-07
#
# Current Epoch 20/25 | Training Loss: 0.3310756212786624 | Training Accuracy: 0.9897610921501706
# Current Epoch: 20/25 | Validation Loss: 0.4123286306858063 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 7.8125e-07
#
# Current Epoch 21/25 | Training Loss: 0.33716188449608653 | Training Accuracy: 0.9829351535836177
# Current Epoch: 21/25 | Validation Loss: 0.41285240650177 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 7.8125e-07
#
# Current Epoch 22/25 | Training Loss: 0.34548469593650416 | Training Accuracy: 0.9692832764505119
# Current Epoch: 22/25 | Validation Loss: 0.41010530789693195 | Validation Accuracy: 0.8888888888888888
# Current Learning Rate: 3.90625e-07
#
# Current Epoch 23/25 | Training Loss: 0.336001455783844 | Training Accuracy: 0.9897610921501706
# Current Epoch: 23/25 | Validation Loss: 0.4239301184813182 | Validation Accuracy: 0.8333333333333334
# Current Learning Rate: 3.90625e-07
#
# Current Epoch 24/25 | Training Loss: 0.3404181348650079 | Training Accuracy: 0.9897610921501706
# Current Epoch: 24/25 | Validation Loss: 0.416452556848526 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 3.90625e-07
#
# Current Epoch 25/25 | Training Loss: 0.33324892269937617 | Training Accuracy: 0.9931740614334471
# Current Epoch: 25/25 | Validation Loss: 0.42120929559071857 | Validation Accuracy: 0.8611111111111112
# Current Learning Rate: 1.953125e-07

# %%
for epoch in range(epochs):
    # training
    train_loss, train_accuracy = train_epoch(model, train_loader, optimizer, loss_function, device)

    # validation
    val_loss, val_accuracy = evaluate_epoch(model, valid_loader, loss_function, device)

    # scheduler to adjust learning rate
    adjust_lr(optimizer, scheduler, val_loss)

    # Get current learning rate while training
    curr_lr = current_learning_rate(optimizer)

    print(f'Current Epoch {epoch + 1}/{epochs} | Training Loss: {train_loss} | Training Accuracy: {train_accuracy}')
    print(f'Current Epoch: {epoch + 1}/{epochs} | Validation Loss: {val_loss} | Validation Accuracy: {val_accuracy}')
    print(f'Current Learning Rate: {curr_lr}\n')

# %% [markdown]
# # **`Testing the Model`**

# %%
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=2, bias=True)
#     (4): Softmax(dim=-1)
#   )
# )

# %% [markdown]
# Let's see our model accuracy on both datasets:

# %%
def accuracy(loader, dataset):
    total = 0
    correct = 0

    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    print(f'{dataset} accuracy: {accuracy}')

# train data accuracy
accuracy(train_loader, "Training data")

# test data accuracy
accuracy(test_loader, 'Test data')
# Out:
# Training data accuracy: 0.9931740614334471
# Test data accuracy: 0.9210526315789473

# %% [markdown]
# Model 1: Train acc - `1.0`, test acc - `94.74%`
#
# Model 2: Training data accuracy: `0.9931740614334471` - Test data accuracy: `0.8947368421052632`
#
# Model 3: Training data accuracy: `0.9931740614334471` - Test data accuracy: `0.9210526315789473`
#
# Model 4: Training data accuracy: `0.9931740614334471` - Test data accuracy: `0.9210526315789473` (increased weight decay from 1e-6 to 1e-4, same result as Model 3)

# %% [markdown]
# We can finally save the trained model

# %%
torch.save(model.state_dict(), 'AwakeDrowsyResnet18_4.pth')

# %% [markdown]
# # **`Loading & Evaluating the Model 3`**

# %% [markdown]
# Specifying architecture of model 3 or 4

# %%
model_3 = models.resnet18(pretrained=True)

model_3.fc = nn.Sequential(
    nn.Linear(model_3.fc.in_features, 128),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Linear(128, 2),
    nn.Softmax()
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_3.load_state_dict(torch.load('resnet_results/AwakeDrowsyResnet18_4.pth'))
# Out:
# <All keys matched successfully>

# %%
model_3.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=2, bias=True)
#     (4): Softmax(dim=None)
#   )
# )

# %%
summary(model_3, (3, 320, 320))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 160, 160]           9,408
#        BatchNorm2d-2         [-1, 64, 160, 160]             128
#               ReLU-3         [-1, 64, 160, 160]               0
#          MaxPool2d-4           [-1, 64, 80, 80]               0
#             Conv2d-5           [-1, 64, 80, 80]          36,864
#        BatchNorm2d-6           [-1, 64, 80, 80]             128
#               ReLU-7           [-1, 64, 80, 80]               0
#             Conv2d-8           [-1, 64, 80, 80]          36,864
#        BatchNorm2d-9           [-1, 64, 80, 80]             128
#              ReLU-10           [-1, 64, 80, 80]               0
#        BasicBlock-11           [-1, 64, 80, 80]               0
#            Conv2d-12           [-1, 64, 80, 80]          36,864
#       BatchNorm2d-13           [-1, 64, 80, 80]             128
#              ReLU-14           [-1, 64, 80, 80]               0
#            Conv2d-15           [-1, 64, 80, 80]          36,864
#       BatchNorm2d-16           [-1, 64, 80, 80]             128
#              ReLU-17           [-1, 64, 80, 80]               0
#        BasicBlock-18           [-1, 64, 80, 80]               0
#            Conv2d-19          [-1, 128, 40, 40]          73,728
#       BatchNorm2d-20          [-1, 128, 40, 40]             256
#              ReLU-21          [-1, 128, 40, 40]               0
#            Conv2d-22          [-1, 128, 40, 40]         147,456
#       BatchNorm2d-23          [-1, 128, 40, 40]             256
#            Conv2d-24          [-1, 128, 40, 40]           8,192
#       BatchNorm2d-25          [-1, 128, 40, 40]             256
#              ReLU-26          [-1, 128, 40, 40]               0
#        BasicBlock-27          [-1, 128, 40, 40]               0
#            Conv2d-28          [-1, 128, 40, 40]         147,456
#       BatchNorm2d-29          [-1, 128, 40, 40]             256
#              ReLU-30          [-1, 128, 40, 40]               0
#            Conv2d-31          [-1, 128, 40, 40]         147,456
#       BatchNorm2d-32          [-1, 128, 40, 40]             256
#              ReLU-33          [-1, 128, 40, 40]               0
#        BasicBlock-34          [-1, 128, 40, 40]               0
#            Conv2d-35          [-1, 256, 20, 20]         294,912
#       BatchNorm2d-36          [-1, 256, 20, 20]             512
#              ReLU-37          [-1, 256, 20, 20]               0
#            Conv2d-38          [-1, 256, 20, 20]         589,824
#       BatchNorm2d-39          [-1, 256, 20, 20]             512
#            Conv2d-40          [-1, 256, 20, 20]          32,768
#       BatchNorm2d-41          [-1, 256, 20, 20]             512
#              ReLU-42          [-1, 256, 20, 20]               0
#        BasicBlock-43          [-1, 256, 20, 20]               0
#            Conv2d-44          [-1, 256, 20, 20]         589,824
#       BatchNorm2d-45          [-1, 256, 20, 20]             512
#              ReLU-46          [-1, 256, 20, 20]               0
#            Conv2d-47          [-1, 256, 20, 20]         589,824
#       BatchNorm2d-48          [-1, 256, 20, 20]             512
#              ReLU-49          [-1, 256, 20, 20]               0
#        BasicBlock-50          [-1, 256, 20, 20]               0
#            Conv2d-51          [-1, 512, 10, 10]       1,179,648
#       BatchNorm2d-52          [-1, 512, 10, 10]           1,024
#              ReLU-53          [-1, 512, 10, 10]               0
#            Conv2d-54          [-1, 512, 10, 10]       2,359,296
#       BatchNorm2d-55          [-1, 512, 10, 10]           1,024
#            Conv2d-56          [-1, 512, 10, 10]         131,072
#       BatchNorm2d-57          [-1, 512, 10, 10]           1,024
#              ReLU-58          [-1, 512, 10, 10]               0
#        BasicBlock-59          [-1, 512, 10, 10]               0
#            Conv2d-60          [-1, 512, 10, 10]       2,359,296
#       BatchNorm2d-61          [-1, 512, 10, 10]           1,024
#              ReLU-62          [-1, 512, 10, 10]               0
#            Conv2d-63          [-1, 512, 10, 10]       2,359,296
#       BatchNorm2d-64          [-1, 512, 10, 10]           1,024
#              ReLU-65          [-1, 512, 10, 10]               0
#        BasicBlock-66          [-1, 512, 10, 10]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                  [-1, 128]          65,664
#              ReLU-69                  [-1, 128]               0
#           Dropout-70                  [-1, 128]               0
#            Linear-71                    [-1, 2]             258
#           Softmax-72                    [-1, 2]               0
# ================================================================
# Total params: 11,242,434
# Trainable params: 11,242,434
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.17
# Forward/backward pass size (MB): 128.13
# Params size (MB): 42.89
# Estimated Total Size (MB): 172.19
# ----------------------------------------------------------------
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_3.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=128, out_features=2, bias=True)
#     (4): Softmax(dim=None)
#   )
# )

# %% [markdown]
# **`Producing Metrics for Model 3`**

# %%
def create_metrics(loader, dataset):
    true_labels = []
    predicted_labels = []

    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_3(inputs)
            _, predicted = torch.max(outputs.data, 1)

            true_labels.extend(labels.cpu().numpy() == 1) # Drowsy is our positive class
            predicted_labels.extend(predicted.cpu().numpy())

    accuracy = accuracy_score(true_labels, predicted_labels)
    precision = precision_score(true_labels, predicted_labels)
    recall = recall_score(true_labels, predicted_labels)
    f1_score_value = f1_score(true_labels, predicted_labels)

    print(f'{dataset} Metrics:')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1 Score: {f1_score_value}')

# lets now calculate the metrics on the train, test and validation sets:
create_metrics(train_loader, 'Training Data')
create_metrics(test_loader, 'Test Data')
create_metrics(valid_loader, 'Validation Data')
# Out:
# Training Data Metrics:
# Accuracy: 0.9897610921501706
# Precision: 0.9862068965517241
# Recall: 0.9930555555555556
# F1 Score: 0.9896193771626298
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Test Data Metrics:
# Accuracy: 0.9210526315789473
# Precision: 0.8636363636363636
# Recall: 1.0
# F1 Score: 0.9268292682926829
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# Validation Data Metrics:
# Accuracy: 0.8611111111111112
# Precision: 0.782608695652174
# Recall: 1.0
# F1 Score: 0.878048780487805

# %% [markdown]
# **`Let's do some live detection/classification`**

# %% [markdown]
# Using the same transformations as done on test data

# %%
live_detection_transform = transform_pipeline_test

# %%
app = FaceAnalysis(name='buffalo_l')
app.prepare(ctx_id=0, det_size=(320, 320))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:69: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /Users/oscaramirmansour/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (320, 320)

# %%
capture = cv2.VideoCapture(0)

cv2.namedWindow('LIVE - InsightFace Detecting', cv2.WINDOW_NORMAL)

cv2.resizeWindow('LIVE - InsightFace Detecting', 800, 600)

while True:
    ret, frame = capture.read()

    faces = app.get(frame)

    for face in faces:
        bbox = face.bbox.astype(int)
        cv2.rectangle(frame, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)

        image_crop = frame[bbox[1]:bbox[3], bbox[0]:bbox[2], :]

        pil_image = PIL.Image.fromarray(image_crop)

        input_tensor = live_detection_transform(pil_image).unsqueeze(0).to(device)

        with torch.no_grad():
            outputs = model_3(input_tensor)

            _, pred_class = torch.max(outputs, 1)

            cv2.putText(frame, f'Class: {pred_class.item()}', (bbox[0], bbox[3] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
        
    cv2.imshow('LIVE - InsightFace Detecting', image_crop)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()
